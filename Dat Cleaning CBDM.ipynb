# %%
# Data handling and manipulation library
import pandas as pd
# Data visualization library based on matplotlib
import seaborn as sns
# Basic plotting library in Python
import matplotlib.pyplot as plt
# Cross-validation function to evaluate model performance
from sklearn.model_selection import cross_val_score
# Library for numerical operations in Python
import numpy as np
# Preprocessing tool to standardize features (mean=0, variance=1)
from sklearn.preprocessing import StandardScaler
# Principal Component Analysis (PCA) for dimensionality reduction
from sklearn.decomposition import PCA
# Visualization tool for the elbow method to determine the optimal number of clusters
from yellowbrick.cluster.elbow import kelbow_visualizer
from yellowbrick.cluster import KElbowVisualizer
# Calculates the Silhouette Score which measures the quality of clusters
from sklearn.metrics import silhouette_score
# KMeans clustering algorithm
from sklearn.cluster import KMeans
# Imputation functions
from sklearn.impute import KNNImputer, SimpleImputer
# Library for interactive plotting 
import plotly
# Module for creating various chart types (like scatter plots)
import plotly.graph_objects as go
# Simplified module for creating visualizations in Plotly
import plotly.express as px
# k-Nearest Neighbors classifier
from sklearn.neighbors import KNeighborsClassifier
# Splits data into random train and test subsets
from sklearn.model_selection import train_test_split
# Generates a confusion matrix
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### Data cleaning and preprocessing
#
# In the first part of this notebook, the focus will be on preparing and cleaning the data for subsequent analysis. The main principles will be covered for some of the features, and it is up to you to do it for the remaining features.

# %%
df = pd.read_csv('data/descriptives.csv')

# %% [markdown]
# Step 1: Discard uniformative features.

# %%
cols_to_drop = []

# Since patient_id, conversation_id and name are unique to each patient and conversation,
#  they are not useful for clustering/classification. They will become important later though
cols_to_drop.append('patient_id')
cols_to_drop.append('name')
cols_to_drop.append('conversation_id')

# %%
#To get a sense of which features offer meaningful information, we print out the frequency of each
#value for each feature

Nrows = df.shape[0]
# Go through each column except for the ones we want to drop
for col in df.columns.drop(cols_to_drop):
    # get unique values in column
    unique = df[col].unique();
    print("\n", col,":")
    # calculate frequency of each value
    for val in unique:
        if val not in ['nan']:
            N = len(df[df[col] == val])
            print("Value, N observations, frequency :", val," ,", N, " ,", np.round(N/Nrows,3))

    print("No. of NANs ", len(df[df[col].isna()]))
# Out:
#  gender :
# Value, N observations, frequency : Female  , 159  , 0.53
# Value, N observations, frequency : Male  , 141  , 0.47
# No. of NANs  0
#
#  age :
# Value, N observations, frequency : 45  , 83  , 0.277
# Value, N observations, frequency : 32  , 60  , 0.2
# Value, N observations, frequency : 28  , 16  , 0.053
# Value, N observations, frequency : 35  , 88  , 0.293
# Value, N observations, frequency : 24  , 1  , 0.003
# Value, N observations, frequency : 40  , 10  , 0.033
# Value, N observations, frequency : 36  , 3  , 0.01
# Value, N observations, frequency : 30  , 13  , 0.043
# Value, N observations, frequency : 25  , 4  , 0.013
# Value, N observations, frequency : 38  , 3  , 0.01
# Value, N observations, frequency : 55  , 7  , 0.023
# Value, N observations, frequency : 57  , 1  , 0.003
# Value, N observations, frequency : 42  , 4  , 0.013
# Value, N observations, frequency : 10  , 1  , 0.003
# Value, N observations, frequency : 31  , 2  , 0.007
# Value, N observations, frequency : 20  , 1  , 0.003
# Value, N observations, frequency : 22  , 1  , 0.003
# Value, N observations, frequency : 65  , 2  , 0.007
# No. of NANs  0
#
#  ethnicity :
# Value, N observations, frequency : Bulgarian  , 1  , 0.003
# Value, N observations, frequency : French  , 8  , 0.027
# Value, N observations, frequency : Nigerian  , 4  , 0.013
# Value, N observations, frequency : Japanese  , 9  , 0.03
# Value, N observations, frequency : Bangladeshi  , 1  , 0.003
# Value, N observations, frequency : Chinese  , 13  , 0.043
# Value, N observations, frequency : Scottish  , 1  , 0.003
# Value, N observations, frequency : German  , 3  , 0.01
# Value, N observations, frequency : Indian  , 11  , 0.037
# Value, N observations, frequency : Mexican  , 11  , 0.037
# Value, N observations, frequency : Kenyan  , 3  , 0.01
# Value, N observations, frequency : Syrian  , 1  , 0.003
# Value, N observations, frequency : Egyptian  , 9  , 0.03
# Value, N observations, frequency : Russian  , 12  , 0.04
# Value, N observations, frequency : Asian  , 5  , 0.017
# Value, N observations, frequency : British  , 4  , 0.013
# Value, N observations, frequency : Norwegian  , 2  , 0.007
# Value, N observations, frequency : Spanish  , 3  , 0.01
# Value, N observations, frequency : Canadian  , 2  , 0.007
# Value, N observations, frequency : Bengali  , 1  , 0.003
# Value, N observations, frequency : Cuban  , 7  , 0.023
# Value, N observations, frequency : Caucasian  , 6  , 0.02
# Value, N observations, frequency : Portuguese  , 3  , 0.01
# Value, N observations, frequency : Korean  , 10  , 0.033
# Value, N observations, frequency : Polish  , 5  , 0.017
# Value, N observations, frequency : Irish  , 6  , 0.02
# Value, N observations, frequency : Italian  , 9  , 0.03
# Value, N observations, frequency : Cypriot  , 1  , 0.003
# Value, N observations, frequency : Thai  , 1  , 0.003
# Value, N observations, frequency : African  , 6  , 0.02
# Value, N observations, frequency : Greek  , 5  , 0.017
# Value, N observations, frequency : Jamaican  , 6  , 0.02
# Value, N observations, frequency : Hispanic  , 6  , 0.02
# Value, N observations, frequency : Pakistani  , 6  , 0.02
# Value, N observations, frequency : Finnish  , 1  , 0.003
# Value, N observations, frequency : Middle Eastern  , 5  , 0.017
# Value, N observations, frequency : Icelandic  , 1  , 0.003
# Value, N observations, frequency : Indonesian  , 3  , 0.01
# Value, N observations, frequency : Ukrainian  , 5  , 0.017
# Value, N observations, frequency : Ghanian  , 1  , 0.003
# Value, N observations, frequency : African American  , 9  , 0.03
# Value, N observations, frequency : Dominican  , 3  , 0.01
# Value, N observations, frequency : Puerto Rican  , 1  , 0.003
# Value, N observations, frequency : Venezuelan  , 1  , 0.003
# Value, N observations, frequency : Turkish  , 2  , 0.007
# Value, N observations, frequency : Jewish  , 5  , 0.017
# Value, N observations, frequency : Nepali  , 1  , 0.003
# Value, N observations, frequency : Somali  , 5  , 0.017
# Value, N observations, frequency : Lebanese  , 4  , 0.013
# Value, N observations, frequency : Iraqi  , 1  , 0.003
# Value, N observations, frequency : Argentinian  , 3  , 0.01
# Value, N observations, frequency : Israeli  , 3  , 0.01
# Value, N observations, frequency : Saudi Arabian  , 1  , 0.003
# Value, N observations, frequency : Hawaiian  , 1  , 0.003
# Value, N observations, frequency : Brazilian  , 6  , 0.02
# Value, N observations, frequency : Moroccan  , 5  , 0.017
# Value, N observations, frequency : Latino  , 1  , 0.003
# Value, N observations, frequency : South African  , 1  , 0.003
# Value, N observations, frequency : Kiwi  , 1  , 0.003
# Value, N observations, frequency : Ghanaian  , 1  , 0.003
# Value, N observations, frequency : African-American  , 1  , 0.003
# Value, N observations, frequency : South Korean  , 1  , 0.003
# Value, N observations, frequency : Palestinian  , 1  , 0.003
# Value, N observations, frequency : Chilean  , 2  , 0.007
# Value, N observations, frequency : Persian  , 1  , 0.003
# Value, N observations, frequency : Vietnamese  , 2  , 0.007
# Value, N observations, frequency : Colombian  , 5  , 0.017
# Value, N observations, frequency : European  , 2  , 0.007
# Value, N observations, frequency : Romanian  , 1  , 0.003
# Value, N observations, frequency : Taiwanese  , 1  , 0.003
# Value, N observations, frequency : Latina  , 1  , 0.003
# Value, N observations, frequency : Belgian  , 2  , 0.007
# Value, N observations, frequency : Swedish  , 4  , 0.013
# Value, N observations, frequency : Fijian  , 1  , 0.003
# Value, N observations, frequency : Filipino  , 1  , 0.003
# Value, N observations, frequency : Native American  , 2  , 0.007
# Value, N observations, frequency : Iranian  , 3  , 0.01
# Value, N observations, frequency : Haitian  , 1  , 0.003
# Value, N observations, frequency : Gujarati  , 1  , 0.003
# Value, N observations, frequency : Malaysian  , 2  , 0.007
# Value, N observations, frequency : Guatemalan  , 1  , 0.003
# Value, N observations, frequency : Trinidadian  , 1  , 0.003
# Value, N observations, frequency : Mongolian  , 1  , 0.003
# Value, N observations, frequency : Algerian  , 1  , 0.003
# Value, N observations, frequency : Arab  , 2  , 0.007
# Value, N observations, frequency : New Zealander  , 1  , 0.003
# Value, N observations, frequency : Afghan  , 1  , 0.003
# Value, N observations, frequency : Emirati  , 1  , 0.003
# Value, N observations, frequency : Yemeni  , 1  , 0.003
# Value, N observations, frequency : Australian  , 1  , 0.003
# Value, N observations, frequency : Sudanese  , 1  , 0.003
# Value, N observations, frequency : Slavic  , 1  , 0.003
# No. of NANs  0
#
#  country_of_birth :
# Value, N observations, frequency : Bulgaria  , 1  , 0.003
# Value, N observations, frequency : France  , 8  , 0.027
# Value, N observations, frequency : Nigeria  , 7  , 0.023
# Value, N observations, frequency : Japan  , 9  , 0.03
# Value, N observations, frequency : Bangladesh  , 2  , 0.007
# Value, N observations, frequency : China  , 18  , 0.06
# Value, N observations, frequency : Scotland  , 1  , 0.003
# Value, N observations, frequency : Germany  , 4  , 0.013
# Value, N observations, frequency : India  , 12  , 0.04
# Value, N observations, frequency : Mexico  , 19  , 0.063
# Value, N observations, frequency : Kenya  , 3  , 0.01
# Value, N observations, frequency : Syria  , 1  , 0.003
# Value, N observations, frequency : Egypt  , 10  , 0.033
# Value, N observations, frequency : Russia  , 13  , 0.043
# Value, N observations, frequency : United Kingdom  , 4  , 0.013
# Value, N observations, frequency : Norway  , 2  , 0.007
# Value, N observations, frequency : Spain  , 3  , 0.01
# Value, N observations, frequency : Canada  , 2  , 0.007
# Value, N observations, frequency : Cuba  , 7  , 0.023
# Value, N observations, frequency : United States  , 24  , 0.08
# Value, N observations, frequency : Portugal  , 3  , 0.01
# Value, N observations, frequency : South Korea  , 11  , 0.037
# Value, N observations, frequency : Poland  , 5  , 0.017
# Value, N observations, frequency : Ireland  , 7  , 0.023
# Value, N observations, frequency : Italy  , 9  , 0.03
# Value, N observations, frequency : Cyprus  , 1  , 0.003
# Value, N observations, frequency : Thailand  , 1  , 0.003
# Value, N observations, frequency : South Africa  , 3  , 0.01
# Value, N observations, frequency : Greece  , 5  , 0.017
# Value, N observations, frequency : Jamaica  , 6  , 0.02
# Value, N observations, frequency : Pakistan  , 6  , 0.02
# Value, N observations, frequency : Finland  , 1  , 0.003
# Value, N observations, frequency : Iran  , 6  , 0.02
# Value, N observations, frequency : Iceland  , 1  , 0.003
# Value, N observations, frequency : Jordan  , 2  , 0.007
# Value, N observations, frequency : Indonesia  , 3  , 0.01
# Value, N observations, frequency : Ukraine  , 5  , 0.017
# Value, N observations, frequency : Ghana  , 2  , 0.007
# Value, N observations, frequency : Dominican Republic  , 3  , 0.01
# Value, N observations, frequency : Puerto Rico  , 1  , 0.003
# Value, N observations, frequency : Venezuela  , 1  , 0.003
# Value, N observations, frequency : Turkey  , 2  , 0.007
# Value, N observations, frequency : Nepal  , 1  , 0.003
# Value, N observations, frequency : Somalia  , 5  , 0.017
# Value, N observations, frequency : Lebanon  , 5  , 0.017
# Value, N observations, frequency : Iraq  , 1  , 0.003
# Value, N observations, frequency : Argentina  , 3  , 0.01
# Value, N observations, frequency : Israel  , 3  , 0.01
# Value, N observations, frequency : Saudi Arabia  , 1  , 0.003
# Value, N observations, frequency : Hawaii  , 1  , 0.003
# Value, N observations, frequency : Brazil  , 6  , 0.02
# Value, N observations, frequency : Morocco  , 5  , 0.017
# Value, N observations, frequency : New Zealand  , 2  , 0.007
# Value, N observations, frequency : Middle Eastern  , 1  , 0.003
# Value, N observations, frequency : Palestine  , 1  , 0.003
# Value, N observations, frequency : Chile  , 2  , 0.007
# Value, N observations, frequency : Vietnam  , 2  , 0.007
# Value, N observations, frequency : Colombia  , 5  , 0.017
# Value, N observations, frequency : Romania  , 1  , 0.003
# Value, N observations, frequency : Taiwan  , 1  , 0.003
# Value, N observations, frequency : Belgium  , 2  , 0.007
# Value, N observations, frequency : Sweden  , 4  , 0.013
# Value, N observations, frequency : Fiji  , 1  , 0.003
# Value, N observations, frequency : Philippines  , 1  , 0.003
# Value, N observations, frequency : Haiti  , 1  , 0.003
# Value, N observations, frequency : Malaysia  , 2  , 0.007
# Value, N observations, frequency : Guatemala  , 1  , 0.003
# Value, N observations, frequency : Trinidad and Tobago  , 1  , 0.003
# Value, N observations, frequency : Mongolia  , 1  , 0.003
# Value, N observations, frequency : Algeria  , 1  , 0.003
# Value, N observations, frequency : Afghanistan  , 1  , 0.003
# Value, N observations, frequency : United Arab Emirates  , 1  , 0.003
# Value, N observations, frequency : Yemen  , 1  , 0.003
# Value, N observations, frequency : Australia  , 1  , 0.003
# Value, N observations, frequency : Sudan  , 1  , 0.003
# No. of NANs  0
#
#  current_country_of_residence :
# Value, N observations, frequency : United States  , 300  , 1.0
# No. of NANs  0
#
#  weight :
# Value, N observations, frequency : 70  , 33  , 0.11
# Value, N observations, frequency : 62.5  , 9  , 0.03
# Value, N observations, frequency : 65  , 61  , 0.203
# Value, N observations, frequency : 75  , 58  , 0.193
# Value, N observations, frequency : 55  , 8  , 0.027
# Value, N observations, frequency : 85  , 27  , 0.09
# Value, N observations, frequency : 62  , 4  , 0.013
# Value, N observations, frequency : 75.2  , 2  , 0.007
# Value, N observations, frequency : 52.5  , 3  , 0.01
# Value, N observations, frequency : 60  , 16  , 0.053
# Value, N observations, frequency : 110  , 1  , 0.003
# Value, N observations, frequency : 72 kg  , 1  , 0.003
# Value, N observations, frequency : 68.5  , 20  , 0.067
# Value, N observations, frequency : 55.2  , 1  , 0.003
# Value, N observations, frequency : 95  , 3  , 0.01
# Value, N observations, frequency : 65.2  , 11  , 0.037
# Value, N observations, frequency : 95.5  , 2  , 0.007
# Value, N observations, frequency : 80  , 18  , 0.06
# Value, N observations, frequency : 85.5  , 4  , 0.013
# Value, N observations, frequency : 78.5  , 4  , 0.013
# Value, N observations, frequency : 58.5  , 3  , 0.01
# Value, N observations, frequency : 60.5  , 1  , 0.003
# Value, N observations, frequency : 70.5  , 3  , 0.01
# Value, N observations, frequency : nan  , 0  , 0.0
# Value, N observations, frequency : 68  , 1  , 0.003
# Value, N observations, frequency : 150  , 1  , 0.003
# Value, N observations, frequency : 68 kg  , 1  , 0.003
# Value, N observations, frequency : 90  , 1  , 0.003
# Value, N observations, frequency : 58  , 1  , 0.003
# Value, N observations, frequency : 55.5  , 1  , 0.003
# No. of NANs  1
#
#  height :
# Value, N observations, frequency : 165  , 108  , 0.36
# Value, N observations, frequency : 160  , 45  , 0.15
# Value, N observations, frequency : 175  , 50  , 0.167
# Value, N observations, frequency : 180  , 78  , 0.26
# Value, N observations, frequency : 170  , 11  , 0.037
# Value, N observations, frequency : 180 cm  , 1  , 0.003
# Value, N observations, frequency : 178  , 1  , 0.003
# Value, N observations, frequency : 162  , 3  , 0.01
# Value, N observations, frequency : 150  , 1  , 0.003
# Value, N observations, frequency : nan  , 0  , 0.0
# Value, N observations, frequency : 165 cm  , 1  , 0.003
# No. of NANs  1
#
#  bmi :
# Value, N observations, frequency : 25.71  , 9  , 0.03
# Value, N observations, frequency : 22.92  , 1  , 0.003
# Value, N observations, frequency : 23.87  , 43  , 0.143
# Value, N observations, frequency : 25.39  , 9  , 0.03
# Value, N observations, frequency : 25.4  , 11  , 0.037
# Value, N observations, frequency : 22.86  , 12  , 0.04
# Value, N observations, frequency : 23.15  , 43  , 0.143
# Value, N observations, frequency : 21.48  , 1  , 0.003
# Value, N observations, frequency : 26.23  , 19  , 0.063
# Value, N observations, frequency : 24.2  , 5  , 0.017
# Value, N observations, frequency : 24.49  , 9  , 0.03
# Value, N observations, frequency : 23.2  , 1  , 0.003
# Value, N observations, frequency : 19.2  , 2  , 0.007
# Value, N observations, frequency : 23.4  , 5  , 0.017
# Value, N observations, frequency : 35.92  , 1  , 0.003
# Value, N observations, frequency : 22.04  , 9  , 0.03
# Value, N observations, frequency : 22.2  , 1  , 0.003
# Value, N observations, frequency : 22.4  , 4  , 0.013
# Value, N observations, frequency : 20.2  , 2  , 0.007
# Value, N observations, frequency : 23.88  , 2  , 0.007
# Value, N observations, frequency : 21.5  , 6  , 0.02
# Value, N observations, frequency : 29.32  , 2  , 0.007
# Value, N observations, frequency : 25.1  , 4  , 0.013
# Value, N observations, frequency : 29.3  , 2  , 0.007
# Value, N observations, frequency : 23.9  , 7  , 0.023
# Value, N observations, frequency : 24.22  , 1  , 0.003
# Value, N observations, frequency : 31.1  , 1  , 0.003
# Value, N observations, frequency : 24.7  , 3  , 0.01
# Value, N observations, frequency : 22.8  , 3  , 0.01
# Value, N observations, frequency : 26.39  , 1  , 0.003
# Value, N observations, frequency : 22.49  , 1  , 0.003
# Value, N observations, frequency : 27.5  , 3  , 0.01
# Value, N observations, frequency : 27.7  , 1  , 0.003
# Value, N observations, frequency : 25.2  , 9  , 0.03
# Value, N observations, frequency : 27.6  , 1  , 0.003
# Value, N observations, frequency : 24.27  , 1  , 0.003
# Value, N observations, frequency : 26.1  , 3  , 0.01
# Value, N observations, frequency : 22.85  , 1  , 0.003
# Value, N observations, frequency : 31.0  , 1  , 0.003
# Value, N observations, frequency : 27.8  , 4  , 0.013
# Value, N observations, frequency : 26.97  , 1  , 0.003
# Value, N observations, frequency : 27.3  , 4  , 0.013
# Value, N observations, frequency : 22.3  , 1  , 0.003
# Value, N observations, frequency : 24.69  , 6  , 0.02
# Value, N observations, frequency : 23.6  , 1  , 0.003
# Value, N observations, frequency : 25.6  , 3  , 0.01
# Value, N observations, frequency : 26.12  , 5  , 0.017
# Value, N observations, frequency : 26.67  , 1  , 0.003
# Value, N observations, frequency : 31.22  , 3  , 0.01
# Value, N observations, frequency : 24.4  , 1  , 0.003
# Value, N observations, frequency : 23.0  , 3  , 0.01
# Value, N observations, frequency : 25.9  , 1  , 0.003
# Value, N observations, frequency : 21.6  , 2  , 0.007
# Value, N observations, frequency : 22.9  , 1  , 0.003
# Value, N observations, frequency : 22.96  , 4  , 0.013
# Value, N observations, frequency : 20.76  , 1  , 0.003
# Value, N observations, frequency : 26.76  , 2  , 0.007
# Value, N observations, frequency : 26.4  , 1  , 0.003
# Value, N observations, frequency : nan  , 0  , 0.0
# Value, N observations, frequency : 24.98  , 1  , 0.003
# Value, N observations, frequency : 20.41  , 1  , 0.003
# Value, N observations, frequency : 31.2  , 1  , 0.003
# Value, N observations, frequency : 25.7  , 1  , 0.003
# Value, N observations, frequency : 48.98  , 1  , 0.003
# Value, N observations, frequency : 25.03  , 1  , 0.003
# Value, N observations, frequency : 31.25  , 1  , 0.003
# Value, N observations, frequency : 31.14  , 1  , 0.003
# Value, N observations, frequency : 22.1  , 1  , 0.003
# Value, N observations, frequency : 19.0  , 1  , 0.003
# Value, N observations, frequency : 20.4  , 1  , 0.003
# Value, N observations, frequency : 27.76  , 1  , 0.003
# Value, N observations, frequency : 20.5  , 1  , 0.003
# Value, N observations, frequency : 31.4  , 1  , 0.003
# No. of NANs  1
#
#  average_daily_step_count :
# Value, N observations, frequency : 7997  , 18  , 0.06
# Value, N observations, frequency : 7895  , 1  , 0.003
# Value, N observations, frequency : 7995  , 15  , 0.05
# Value, N observations, frequency : 8005  , 11  , 0.037
# Value, N observations, frequency : 7992  , 6  , 0.02
# Value, N observations, frequency : 8001  , 12  , 0.04
# Value, N observations, frequency : 8002  , 7  , 0.023
# Value, N observations, frequency : 7993  , 9  , 0.03
# Value, N observations, frequency : 8006  , 14  , 0.047
# Value, N observations, frequency : 7996  , 6  , 0.02
# Value, N observations, frequency : 7999  , 12  , 0.04
# Value, N observations, frequency : 7501  , 2  , 0.007
# Value, N observations, frequency : 7491  , 2  , 0.007
# Value, N observations, frequency : 8009  , 7  , 0.023
# Value, N observations, frequency : 7817  , 3  , 0.01
# Value, N observations, frequency : 8000  , 23  , 0.077
# Value, N observations, frequency : 8004  , 9  , 0.03
# Value, N observations, frequency : 8008  , 8  , 0.027
# Value, N observations, frequency : 7850  , 1  , 0.003
# Value, N observations, frequency : 7998  , 12  , 0.04
# Value, N observations, frequency : 7991  , 15  , 0.05
# Value, N observations, frequency : 8007  , 6  , 0.02
# Value, N observations, frequency : 7450  , 1  , 0.003
# Value, N observations, frequency : 8762  , 1  , 0.003
# Value, N observations, frequency : 7498  , 3  , 0.01
# Value, N observations, frequency : 7505  , 2  , 0.007
# Value, N observations, frequency : 9003  , 1  , 0.003
# Value, N observations, frequency : 7503  , 2  , 0.007
# Value, N observations, frequency : 7853  , 1  , 0.003
# Value, N observations, frequency : 8003  , 14  , 0.047
# Value, N observations, frequency : 7000  , 1  , 0.003
# Value, N observations, frequency : 7566  , 1  , 0.003
# Value, N observations, frequency : 7003  , 2  , 0.007
# Value, N observations, frequency : 7500  , 4  , 0.013
# Value, N observations, frequency : 7793  , 1  , 0.003
# Value, N observations, frequency : 7496  , 5  , 0.017
# Value, N observations, frequency : 8771  , 1  , 0.003
# Value, N observations, frequency : 7506  , 1  , 0.003
# Value, N observations, frequency : 7806  , 1  , 0.003
# Value, N observations, frequency : 7898  , 1  , 0.003
# Value, N observations, frequency : 8447  , 1  , 0.003
# Value, N observations, frequency : 7874  , 1  , 0.003
# Value, N observations, frequency : 7890  , 1  , 0.003
# Value, N observations, frequency : 7492  , 4  , 0.013
# Value, N observations, frequency : 7825  , 1  , 0.003
# Value, N observations, frequency : 7650  , 1  , 0.003
# Value, N observations, frequency : 8504  , 1  , 0.003
# Value, N observations, frequency : 8491  , 1  , 0.003
# Value, N observations, frequency : 7507  , 1  , 0.003
# Value, N observations, frequency : 7994  , 7  , 0.023
# Value, N observations, frequency : 8765  , 1  , 0.003
# Value, N observations, frequency : 8729  , 1  , 0.003
# Value, N observations, frequency : 8500  , 2  , 0.007
# Value, N observations, frequency : 7862  , 1  , 0.003
# Value, N observations, frequency : 7600  , 1  , 0.003
# Value, N observations, frequency : 7820  , 1  , 0.003
# Value, N observations, frequency : 7494  , 3  , 0.01
# Value, N observations, frequency : 6992  , 1  , 0.003
# Value, N observations, frequency : 7495  , 3  , 0.01
# Value, N observations, frequency : 7852  , 1  , 0.003
# Value, N observations, frequency : 7829  , 1  , 0.003
# Value, N observations, frequency : 8774  , 1  , 0.003
# Value, N observations, frequency : 7509  , 2  , 0.007
# Value, N observations, frequency : 7849  , 2  , 0.007
# Value, N observations, frequency : 7493  , 3  , 0.01
# Value, N observations, frequency : 7508  , 1  , 0.003
# Value, N observations, frequency : 7896  , 2  , 0.007
# Value, N observations, frequency : 7588  , 1  , 0.003
# Value, N observations, frequency : 7902  , 1  , 0.003
# Value, N observations, frequency : 7899  , 1  , 0.003
# Value, N observations, frequency : 7447  , 1  , 0.003
# Value, N observations, frequency : 7681  , 1  , 0.003
# Value, N observations, frequency : 8700  , 1  , 0.003
# Value, N observations, frequency : 7822  , 1  , 0.003
# Value, N observations, frequency : 6995  , 1  , 0.003
# Value, N observations, frequency : 8763  , 1  , 0.003
# Value, N observations, frequency : 8764  , 1  , 0.003
# Value, N observations, frequency : 7828  , 1  , 0.003
# Value, N observations, frequency : 7546  , 1  , 0.003
# No. of NANs  0
#
#  average_sleep_duration :
# Value, N observations, frequency : 7.9  , 6  , 0.02
# Value, N observations, frequency : nan  , 0  , 0.0
# Value, N observations, frequency : 7.8  , 9  , 0.03
# Value, N observations, frequency : 7.2  , 10  , 0.033
# Value, N observations, frequency : 6.9  , 3  , 0.01
# Value, N observations, frequency : 7.5  , 24  , 0.08
# Value, N observations, frequency : 7.6  , 9  , 0.03
# Value, N observations, frequency : 7.1  , 5  , 0.017
# Value, N observations, frequency : 8.1  , 3  , 0.01
# Value, N observations, frequency : 7.7  , 4  , 0.013
# Value, N observations, frequency : 7.0  , 6  , 0.02
# Value, N observations, frequency : 7.3  , 3  , 0.01
# Value, N observations, frequency : 8.0  , 2  , 0.007
# Value, N observations, frequency : 6.7  , 1  , 0.003
# No. of NANs  215
#
#  resting_heart_rate :
# Value, N observations, frequency : 75  , 10  , 0.033
# Value, N observations, frequency : 63  , 16  , 0.053
# Value, N observations, frequency : 67  , 18  , 0.06
# Value, N observations, frequency : 65  , 13  , 0.043
# Value, N observations, frequency : 79  , 9  , 0.03
# Value, N observations, frequency : 73  , 13  , 0.043
# Value, N observations, frequency : 72  , 15  , 0.05
# Value, N observations, frequency : 66  , 17  , 0.057
# Value, N observations, frequency : 64  , 12  , 0.04
# Value, N observations, frequency : 61  , 16  , 0.053
# Value, N observations, frequency : 68  , 17  , 0.057
# Value, N observations, frequency : 62  , 16  , 0.053
# Value, N observations, frequency : 76  , 16  , 0.053
# Value, N observations, frequency : 58  , 3  , 0.01
# Value, N observations, frequency : 70  , 31  , 0.103
# Value, N observations, frequency : 71  , 20  , 0.067
# Value, N observations, frequency : 74  , 12  , 0.04
# Value, N observations, frequency : 59  , 4  , 0.013
# Value, N observations, frequency : 60  , 7  , 0.023
# Value, N observations, frequency : 78  , 8  , 0.027
# Value, N observations, frequency : 77  , 11  , 0.037
# Value, N observations, frequency : 69  , 12  , 0.04
# Value, N observations, frequency : 57  , 2  , 0.007
# Value, N observations, frequency : 56  , 2  , 0.007
# No. of NANs  0
#
#  heart_rate_variability :
# Value, N observations, frequency : 51.0  , 11  , 0.037
# Value, N observations, frequency : 61.0  , 12  , 0.04
# Value, N observations, frequency : 54.0  , 14  , 0.047
# Value, N observations, frequency : 66.0  , 9  , 0.03
# Value, N observations, frequency : 65.0  , 16  , 0.053
# Value, N observations, frequency : 55.0  , 8  , 0.027
# Value, N observations, frequency : 58.0  , 12  , 0.04
# Value, N observations, frequency : 71.0  , 5  , 0.017
# Value, N observations, frequency : 62.0  , 15  , 0.05
# Value, N observations, frequency : 53.0  , 12  , 0.04
# Value, N observations, frequency : 78.0  , 2  , 0.007
# Value, N observations, frequency : 63.0  , 18  , 0.06
# Value, N observations, frequency : 57.0  , 14  , 0.047
# Value, N observations, frequency : 68.0  , 8  , 0.027
# Value, N observations, frequency : 83.0  , 1  , 0.003
# Value, N observations, frequency : 60.0  , 27  , 0.09
# Value, N observations, frequency : 74.0  , 2  , 0.007
# Value, N observations, frequency : 69.0  , 13  , 0.043
# Value, N observations, frequency : 56.0  , 18  , 0.06
# Value, N observations, frequency : 64.0  , 13  , 0.043
# Value, N observations, frequency : 59.0  , 8  , 0.027
# Value, N observations, frequency : 77.0  , 3  , 0.01
# Value, N observations, frequency : 52.0  , 9  , 0.03
# Value, N observations, frequency : 84.0  , 2  , 0.007
# Value, N observations, frequency : 67.0  , 14  , 0.047
# Value, N observations, frequency : 70.0  , 7  , 0.023
# Value, N observations, frequency : 47.0  , 1  , 0.003
# Value, N observations, frequency : 79.0  , 7  , 0.023
# Value, N observations, frequency : 76.0  , 4  , 0.013
# Value, N observations, frequency : 81.0  , 3  , 0.01
# Value, N observations, frequency : 73.0  , 2  , 0.007
# Value, N observations, frequency : 72.0  , 2  , 0.007
# Value, N observations, frequency : 75.0  , 2  , 0.007
# Value, N observations, frequency : 82.0  , 1  , 0.003
# Value, N observations, frequency : 50.0  , 1  , 0.003
# Value, N observations, frequency : 49.0  , 1  , 0.003
# Value, N observations, frequency : 0.08  , 1  , 0.003
# Value, N observations, frequency : 88.0  , 1  , 0.003
# Value, N observations, frequency : 45.0  , 1  , 0.003
# No. of NANs  0
#
#  systolic :
# Value, N observations, frequency : 130.0  , 12  , 0.04
# Value, N observations, frequency : nan  , 0  , 0.0
# Value, N observations, frequency : 120.0  , 45  , 0.15
# No. of NANs  243
#
#  diastolic :
# Value, N observations, frequency : 85.0  , 5  , 0.017
# Value, N observations, frequency : nan  , 0  , 0.0
# Value, N observations, frequency : 80.0  , 52  , 0.173
# No. of NANs  243
#
#  average_blood_glucose :
# Value, N observations, frequency : 6.7  , 17  , 0.057
# Value, N observations, frequency : 6.6  , 14  , 0.047
# Value, N observations, frequency : 7.5  , 6  , 0.02
# Value, N observations, frequency : 6.0  , 22  , 0.073
# Value, N observations, frequency : 6.5  , 20  , 0.067
# Value, N observations, frequency : 5.8  , 14  , 0.047
# Value, N observations, frequency : 5.6  , 7  , 0.023
# Value, N observations, frequency : 7.1  , 5  , 0.017
# Value, N observations, frequency : 8.7  , 5  , 0.017
# Value, N observations, frequency : 6.4  , 21  , 0.07
# Value, N observations, frequency : 6.8  , 19  , 0.063
# Value, N observations, frequency : 6.2  , 20  , 0.067
# Value, N observations, frequency : 7.9  , 4  , 0.013
# Value, N observations, frequency : 5.9  , 11  , 0.037
# Value, N observations, frequency : 8.5  , 5  , 0.017
# Value, N observations, frequency : 5.7  , 17  , 0.057
# Value, N observations, frequency : 8.2  , 9  , 0.03
# Value, N observations, frequency : 4.7  , 2  , 0.007
# Value, N observations, frequency : 7.8  , 8  , 0.027
# Value, N observations, frequency : 8.9  , 2  , 0.007
# Value, N observations, frequency : 7.2  , 5  , 0.017
# Value, N observations, frequency : 6.3  , 5  , 0.017
# Value, N observations, frequency : 6.9  , 6  , 0.02
# Value, N observations, frequency : 7.4  , 9  , 0.03
# Value, N observations, frequency : 5.0  , 1  , 0.003
# Value, N observations, frequency : 7.7  , 5  , 0.017
# Value, N observations, frequency : 7.0  , 7  , 0.023
# Value, N observations, frequency : 8.4  , 5  , 0.017
# Value, N observations, frequency : 6.1  , 7  , 0.023
# Value, N observations, frequency : 8.1  , 2  , 0.007
# Value, N observations, frequency : 8.8  , 3  , 0.01
# Value, N observations, frequency : 8.3  , 4  , 0.013
# Value, N observations, frequency : 8.0  , 4  , 0.013
# Value, N observations, frequency : 7.6  , 5  , 0.017
# Value, N observations, frequency : 5.3  , 1  , 0.003
# Value, N observations, frequency : 5.1  , 1  , 0.003
# Value, N observations, frequency : 4.9  , 1  , 0.003
# Value, N observations, frequency : 9.0  , 1  , 0.003
# No. of NANs  0
#
#  average_fasting_glucose :
# Value, N observations, frequency : 6.9  , 3  , 0.01
# Value, N observations, frequency : 6.0  , 15  , 0.05
# Value, N observations, frequency : 5.5  , 9  , 0.03
# Value, N observations, frequency : 7.0  , 12  , 0.04
# Value, N observations, frequency : 7.4  , 8  , 0.027
# Value, N observations, frequency : 6.2  , 19  , 0.063
# Value, N observations, frequency : 7.1  , 8  , 0.027
# Value, N observations, frequency : 8.2  , 5  , 0.017
# Value, N observations, frequency : 5.7  , 9  , 0.03
# Value, N observations, frequency : 6.1  , 13  , 0.043
# Value, N observations, frequency : 7.2  , 12  , 0.04
# Value, N observations, frequency : 7.8  , 9  , 0.03
# Value, N observations, frequency : 7.6  , 7  , 0.023
# Value, N observations, frequency : 6.5  , 7  , 0.023
# Value, N observations, frequency : 6.3  , 21  , 0.07
# Value, N observations, frequency : 5.9  , 8  , 0.027
# Value, N observations, frequency : 5.8  , 14  , 0.047
# Value, N observations, frequency : 5.3  , 6  , 0.02
# Value, N observations, frequency : 8.3  , 3  , 0.01
# Value, N observations, frequency : 6.4  , 19  , 0.063
# Value, N observations, frequency : 8.0  , 7  , 0.023
# Value, N observations, frequency : 6.7  , 2  , 0.007
# Value, N observations, frequency : 5.4  , 10  , 0.033
# Value, N observations, frequency : 6.6  , 8  , 0.027
# Value, N observations, frequency : 6.8  , 9  , 0.03
# Value, N observations, frequency : 7.5  , 10  , 0.033
# Value, N observations, frequency : 8.4  , 2  , 0.007
# Value, N observations, frequency : 7.3  , 13  , 0.043
# Value, N observations, frequency : 5.6  , 7  , 0.023
# Value, N observations, frequency : 7.9  , 6  , 0.02
# Value, N observations, frequency : 5.2  , 6  , 0.02
# Value, N observations, frequency : 7.7  , 7  , 0.023
# Value, N observations, frequency : 8.1  , 3  , 0.01
# Value, N observations, frequency : 9.2  , 1  , 0.003
# Value, N observations, frequency : nan  , 0  , 0.0
# Value, N observations, frequency : 4.7  , 1  , 0.003
# No. of NANs  1
#
#  diet_type :
# Value, N observations, frequency : Mediterranean  , 47  , 0.157
# Value, N observations, frequency : Balanced  , 177  , 0.59
# Value, N observations, frequency : Gluten-free  , 15  , 0.05
# Value, N observations, frequency : Keto  , 1  , 0.003
# Value, N observations, frequency : Diabetic-friendly  , 6  , 0.02
# Value, N observations, frequency : Omnivore  , 7  , 0.023
# Value, N observations, frequency : Low-carb  , 8  , 0.027
# Value, N observations, frequency : Low FODMAP  , 1  , 0.003
# Value, N observations, frequency : Crohn's disease-friendly diet  , 1  , 0.003
# Value, N observations, frequency : Low Protein  , 1  , 0.003
# Value, N observations, frequency : Vegetarian  , 11  , 0.037
# Value, N observations, frequency : Low-FODMAP  , 2  , 0.007
# Value, N observations, frequency : Anti-inflammatory diet  , 1  , 0.003
# Value, N observations, frequency : Gestational  , 1  , 0.003
# Value, N observations, frequency : Plant-based  , 2  , 0.007
# Value, N observations, frequency : Salt-restricted  , 1  , 0.003
# Value, N observations, frequency : Vegan  , 2  , 0.007
# Value, N observations, frequency : Low Glycemic Index  , 2  , 0.007
# Value, N observations, frequency : Intermittent Fasting  , 2  , 0.007
# Value, N observations, frequency : Multiple Sclerosis Diet  , 1  , 0.003
# Value, N observations, frequency : Ayurvedic  , 1  , 0.003
# Value, N observations, frequency : Anti-Inflammatory Diet  , 1  , 0.003
# Value, N observations, frequency : High Protein  , 1  , 0.003
# Value, N observations, frequency : Halal  , 3  , 0.01
# Value, N observations, frequency : Low-sodium  , 1  , 0.003
# Value, N observations, frequency : Balanced Diet  , 2  , 0.007
# Value, N observations, frequency : Anti-inflammatory  , 2  , 0.007
# No. of NANs  0
#
#  specific_preferences :
# Value, N observations, frequency : Vegetarian  , 25  , 0.083
# Value, N observations, frequency : ["Gluten-free","Low dairy"]  , 1  , 0.003
# Value, N observations, frequency : No specific preferences  , 123  , 0.41
# Value, N observations, frequency : Recipes without gluten  , 1  , 0.003
# Value, N observations, frequency : Low-carb, high-fat  , 1  , 0.003
# Value, N observations, frequency : Low sugar, low carbohydrate  , 1  , 0.003
# Value, N observations, frequency : Low-carb  , 22  , 0.073
# Value, N observations, frequency : Avoids gluten and dairy  , 1  , 0.003
# Value, N observations, frequency : nan  , 0  , 0.0
# Value, N observations, frequency : Avoids sugary foods and drinks  , 2  , 0.007
# Value, N observations, frequency : Low carbohydrate  , 2  , 0.007
# Value, N observations, frequency : Avoid dairy and gluten  , 2  , 0.007
# Value, N observations, frequency : Low sugar  , 1  , 0.003
# Value, N observations, frequency : Avoid trigger foods, low fiber intake  , 1  , 0.003
# Value, N observations, frequency : No pork, low sodium  , 1  , 0.003
# Value, N observations, frequency : Celiac-friendly  , 5  , 0.017
# Value, N observations, frequency : Thyroid health  , 1  , 0.003
# Value, N observations, frequency : ["Vegetarian"]  , 2  , 0.007
# Value, N observations, frequency : No red meat, high intake of fruits and vegetables  , 7  , 0.023
# Value, N observations, frequency : ["Vegetarian","Low-sodium"]  , 2  , 0.007
# Value, N observations, frequency : Low-sodium, high-fiber  , 1  , 0.003
# Value, N observations, frequency : Low-sodium, Low-sugar  , 1  , 0.003
# Value, N observations, frequency : Gluten-free  , 1  , 0.003
# Value, N observations, frequency : No dairy  , 8  , 0.027
# Value, N observations, frequency : Low-sodium  , 2  , 0.007
# Value, N observations, frequency : Bone-friendly foods  , 1  , 0.003
# Value, N observations, frequency : Low-carb, low-sugar  , 1  , 0.003
# Value, N observations, frequency : Avoid processed foods  , 4  , 0.013
# Value, N observations, frequency : Gluten-free, dairy-free  , 1  , 0.003
# Value, N observations, frequency : ["Gluten-free"]  , 1  , 0.003
# Value, N observations, frequency : Avoids sugary foods  , 3  , 0.01
# Value, N observations, frequency : Avoids cross-contamination  , 1  , 0.003
# Value, N observations, frequency : Low sodium  , 2  , 0.007
# Value, N observations, frequency : No red meat  , 7  , 0.023
# Value, N observations, frequency : Low sodium, low sugar  , 4  , 0.013
# Value, N observations, frequency : No red meat, high in fruits and vegetables  , 1  , 0.003
# Value, N observations, frequency : Child-friendly, low sugar  , 1  , 0.003
# Value, N observations, frequency : Budget-friendly options  , 1  , 0.003
# Value, N observations, frequency : Chinese cuisine  , 1  , 0.003
# Value, N observations, frequency : ["Low-sodium","High-fiber"]  , 1  , 0.003
# Value, N observations, frequency : Low-carb, high-fiber  , 2  , 0.007
# Value, N observations, frequency : Avoids gluten-containing foods  , 3  , 0.01
# Value, N observations, frequency : Low sugar, low sodium  , 2  , 0.007
# Value, N observations, frequency : Low sodium intake  , 1  , 0.003
# Value, N observations, frequency : No animal products, high in fruits and vegetables  , 1  , 0.003
# Value, N observations, frequency : No red meat, gluten-free  , 1  , 0.003
# Value, N observations, frequency : Low-carb, High-fiber  , 1  , 0.003
# Value, N observations, frequency : No beef or pork  , 2  , 0.007
# Value, N observations, frequency : Weight Management  , 2  , 0.007
# Value, N observations, frequency : Incorporates more root vegetables  , 1  , 0.003
# Value, N observations, frequency : Low-carb, Low-sugar  , 1  , 0.003
# Value, N observations, frequency : Low saturated fat, high omega-3 fatty acids  , 1  , 0.003
# Value, N observations, frequency : Incorporating spicy foods  , 1  , 0.003
# Value, N observations, frequency : Gluten-free, lactose-free  , 1  , 0.003
# Value, N observations, frequency : Low sodium, high fiber  , 2  , 0.007
# Value, N observations, frequency : Avoid processed foods, dairy, and gluten  , 1  , 0.003
# Value, N observations, frequency : No meat or fish  , 1  , 0.003
# Value, N observations, frequency : Low-sugar  , 1  , 0.003
# Value, N observations, frequency : No red meat, low sugar  , 1  , 0.003
# Value, N observations, frequency : Plant-based foods, no animal products  , 1  , 0.003
# Value, N observations, frequency : Avoids processed foods  , 3  , 0.01
# Value, N observations, frequency : ["No seafood","Low sodium"]  , 1  , 0.003
# Value, N observations, frequency : ["Gluten-free","Low-sodium"]  , 1  , 0.003
# Value, N observations, frequency : Protein-rich options  , 1  , 0.003
# Value, N observations, frequency : Protein-rich meals  , 1  , 0.003
# Value, N observations, frequency : ["Vegetarian","Low sodium"]  , 1  , 0.003
# Value, N observations, frequency : Avoids sugary drinks and processed foods  , 1  , 0.003
# Value, N observations, frequency : ["Vegetarian","Gluten-free"]  , 1  , 0.003
# Value, N observations, frequency : Strict adherence to Halal diet  , 1  , 0.003
# Value, N observations, frequency : No pork, no alcohol  , 2  , 0.007
# Value, N observations, frequency : Avoid processed foods and canned goods  , 1  , 0.003
# Value, N observations, frequency : Iron-rich foods  , 1  , 0.003
# Value, N observations, frequency : Phosphorus-rich foods  , 1  , 0.003
# Value, N observations, frequency : Gluten-free, Dairy-free  , 1  , 0.003
# Value, N observations, frequency : Low sugar, high protein  , 1  , 0.003
# Value, N observations, frequency : Incorporate more fruits and vegetables, avoid processed foods  , 1  , 0.003
# Value, N observations, frequency : Celiac disease  , 1  , 0.003
# Value, N observations, frequency : ["Low-carb","High-fiber"]  , 1  , 0.003
# No. of NANs  8
#
#  challenges :
# Value, N observations, frequency : Gluten-free  , 5  , 0.017
# Value, N observations, frequency : Avoiding processed foods  , 67  , 0.223
# Value, N observations, frequency : Maintaining portion control  , 20  , 0.067
# Value, N observations, frequency : Finding suitable ingredients  , 1  , 0.003
# Value, N observations, frequency : Concerns about potential side effects  , 1  , 0.003
# Value, N observations, frequency : Finding tasty dessert alternatives  , 1  , 0.003
# Value, N observations, frequency : Maintaining a balanced diet while traveling  , 1  , 0.003
# Value, N observations, frequency : Maintaining protein intake  , 2  , 0.007
# Value, N observations, frequency : Managing carbohydrate intake while working as a sushi chef  , 1  , 0.003
# Value, N observations, frequency : nan  , 0  , 0.0
# Value, N observations, frequency : Finding suitable alternatives  , 6  , 0.02
# Value, N observations, frequency : Avoiding unhealthy food cravings  , 1  , 0.003
# Value, N observations, frequency : Maintaining a healthy weight  , 2  , 0.007
# Value, N observations, frequency : Managing portion sizes  , 6  , 0.02
# Value, N observations, frequency : Managing sugar intake  , 3  , 0.01
# Value, N observations, frequency : Gestational diabetes  , 1  , 0.003
# Value, N observations, frequency : Difficulty adhering to the diet consistently  , 1  , 0.003
# Value, N observations, frequency : Transitioning to gluten-free diet  , 1  , 0.003
# Value, N observations, frequency : Ensuring nutrient balance  , 1  , 0.003
# Value, N observations, frequency : Morning sickness affecting appetite  , 1  , 0.003
# Value, N observations, frequency : ["Gluten-free"]  , 1  , 0.003
# Value, N observations, frequency : Managing blood glucose levels  , 3  , 0.01
# Value, N observations, frequency : Managing celiac disease in foreign countries  , 1  , 0.003
# Value, N observations, frequency : Avoiding sugary foods  , 4  , 0.013
# Value, N observations, frequency : Limited mobility due to wheelchair  , 2  , 0.007
# Value, N observations, frequency : Gluten intolerance  , 3  , 0.01
# Value, N observations, frequency : Reducing protein intake  , 1  , 0.003
# Value, N observations, frequency : Reducing oil consumption  , 1  , 0.003
# Value, N observations, frequency : Limiting alcohol and caffeine intake  , 1  , 0.003
# Value, N observations, frequency : Managing cravings  , 2  , 0.007
# Value, N observations, frequency : Managing carbohydrate intake  , 2  , 0.007
# Value, N observations, frequency : Finding vegan options when eating out  , 1  , 0.003
# Value, N observations, frequency : Reducing salt in recipes without compromising taste  , 1  , 0.003
# Value, N observations, frequency : Incorporating bone-friendly foods into the diet  , 1  , 0.003
# Value, N observations, frequency : Maintaining a consistent routine while traveling  , 1  , 0.003
# Value, N observations, frequency : Emotional eating  , 6  , 0.02
# Value, N observations, frequency : Avoiding sugary snacks  , 9  , 0.03
# Value, N observations, frequency : Maintaining balanced nutrition during Ramadan fasting  , 1  , 0.003
# Value, N observations, frequency : Cravings for sweets  , 2  , 0.007
# Value, N observations, frequency : ["Avoiding sugary snacks"]  , 1  , 0.003
# Value, N observations, frequency : Limited healthy food options while on the road  , 1  , 0.003
# Value, N observations, frequency : Cravings for high-sodium foods  , 1  , 0.003
# Value, N observations, frequency : Reintroducing certain feared foods  , 1  , 0.003
# Value, N observations, frequency : Maintaining consistency  , 2  , 0.007
# Value, N observations, frequency : Dining out  , 1  , 0.003
# Value, N observations, frequency : Finding suitable options at social events  , 1  , 0.003
# Value, N observations, frequency : Inconsistency in managing hypertension  , 1  , 0.003
# Value, N observations, frequency : Maintaining a balanced diet while climbing  , 1  , 0.003
# Value, N observations, frequency : Avoiding gluten  , 1  , 0.003
# Value, N observations, frequency : Maintaining a balanced diet while breastfeeding  , 1  , 0.003
# Value, N observations, frequency : Lactose intolerance  , 3  , 0.01
# Value, N observations, frequency : Costs associated with gluten-free products  , 1  , 0.003
# Value, N observations, frequency : Difficulty sticking to the diet  , 2  , 0.007
# Value, N observations, frequency : Maintaining the diet during social gatherings  , 1  , 0.003
# Value, N observations, frequency : Managing blood sugar levels  , 1  , 0.003
# Value, N observations, frequency : Managing sugar cravings  , 2  , 0.007
# Value, N observations, frequency : Avoiding sugary desserts  , 1  , 0.003
# Value, N observations, frequency : Managing diabetes  , 1  , 0.003
# Value, N observations, frequency : Feeling left out during social events  , 1  , 0.003
# Value, N observations, frequency : Sugar cravings  , 2  , 0.007
# Value, N observations, frequency : ["Avoiding processed foods"]  , 2  , 0.007
# Value, N observations, frequency : Obesity and nutritional deficiencies  , 1  , 0.003
# Value, N observations, frequency : Accidental gluten exposure  , 1  , 0.003
# Value, N observations, frequency : Staying motivated  , 1  , 0.003
# Value, N observations, frequency : Resistant to changing diet  , 1  , 0.003
# Value, N observations, frequency : Finding vegetarian options while traveling  , 1  , 0.003
# Value, N observations, frequency : Finding suitable options when eating out  , 2  , 0.007
# Value, N observations, frequency : Avoiding temptations  , 1  , 0.003
# Value, N observations, frequency : Avoiding sugary drinks  , 2  , 0.007
# Value, N observations, frequency : Maintaining energy for performances  , 1  , 0.003
# Value, N observations, frequency : Maintaining Consistency  , 1  , 0.003
# Value, N observations, frequency : Reluctance to make lifestyle changes  , 1  , 0.003
# Value, N observations, frequency : Managing Crohn's disease  , 1  , 0.003
# Value, N observations, frequency : Avoiding spicy foods  , 1  , 0.003
# Value, N observations, frequency : Managing weight gain during pregnancy  , 1  , 0.003
# Value, N observations, frequency : Difficulties maintaining gluten-free diet while traveling  , 1  , 0.003
# Value, N observations, frequency : Avoiding cross-contamination in restaurants  , 1  , 0.003
# Value, N observations, frequency : Managing blood glucose levels during Jewish holidays  , 1  , 0.003
# Value, N observations, frequency : Managing sugar intake during Ramadan  , 1  , 0.003
# Value, N observations, frequency : Finding creative meal ideas  , 1  , 0.003
# Value, N observations, frequency : Binge eating  , 1  , 0.003
# Value, N observations, frequency : Managing flare-ups of ulcerative colitis  , 1  , 0.003
# Value, N observations, frequency : Struggling with dietary restrictions  , 1  , 0.003
# Value, N observations, frequency : Binge eating during exams  , 1  , 0.003
# Value, N observations, frequency : Avoiding spicy food  , 1  , 0.003
# Value, N observations, frequency : Avoiding trigger foods  , 2  , 0.007
# Value, N observations, frequency : Finding vegetarian options while eating out  , 2  , 0.007
# Value, N observations, frequency : Finding suitable options while working as a chef  , 1  , 0.003
# Value, N observations, frequency : Quitting smoking  , 1  , 0.003
# Value, N observations, frequency : Managing diabetes while traveling  , 1  , 0.003
# Value, N observations, frequency : Transitioning from a non-vegetarian diet  , 1  , 0.003
# Value, N observations, frequency : Balancing seafood intake  , 1  , 0.003
# Value, N observations, frequency : Managing weight due to inconsistent schedules  , 1  , 0.003
# Value, N observations, frequency : Monotonous bone health regimen  , 1  , 0.003
# Value, N observations, frequency : Post-surgery recovery  , 1  , 0.003
# Value, N observations, frequency : Managing hearty Irish stews  , 1  , 0.003
# Value, N observations, frequency : Avoiding gluten due to sensitivity  , 1  , 0.003
# Value, N observations, frequency : Difficulty finding vegan options when eating out  , 1  , 0.003
# Value, N observations, frequency : Balancing diabetes management with professional dancing  , 1  , 0.003
# Value, N observations, frequency : Avoiding triggers during holiday season  , 1  , 0.003
# Value, N observations, frequency : Managing gluten intake due to close friend's celiac disease  , 1  , 0.003
# Value, N observations, frequency : Balancing diet with social life  , 1  , 0.003
# Value, N observations, frequency : Stress-induced impulse eating  , 1  , 0.003
# Value, N observations, frequency : Family unsupportive of eating disorder recovery  , 1  , 0.003
# Value, N observations, frequency : Avoiding high blood sugar levels  , 1  , 0.003
# Value, N observations, frequency : Maintaining a healthy diet while on long trips  , 1  , 0.003
# Value, N observations, frequency : Maintaining discipline  , 1  , 0.003
# Value, N observations, frequency : Maintaining variety  , 1  , 0.003
# Value, N observations, frequency : Overindulgence in spicy foods  , 1  , 0.003
# Value, N observations, frequency : Reducing water retention  , 1  , 0.003
# Value, N observations, frequency : Giving up smoking  , 1  , 0.003
# Value, N observations, frequency : Cravings for unhealthy snacks  , 2  , 0.007
# Value, N observations, frequency : Limited access to fresh produce  , 1  , 0.003
# Value, N observations, frequency : Maintaining hydration in a desert environment  , 1  , 0.003
# Value, N observations, frequency : Managing Type 2 diabetes while adhering to a Halal diet  , 1  , 0.003
# Value, N observations, frequency : Managing diet during Ramadan  , 1  , 0.003
# Value, N observations, frequency : Finding Halal options while eating out  , 1  , 0.003
# Value, N observations, frequency : Resists making significant lifestyle changes  , 1  , 0.003
# Value, N observations, frequency : Alcoholism recovery  , 1  , 0.003
# Value, N observations, frequency : Finding suitable low-sodium options when eating out  , 1  , 0.003
# Value, N observations, frequency : Finding suitable vegetarian options  , 1  , 0.003
# Value, N observations, frequency : Avoiding binge triggers  , 1  , 0.003
# Value, N observations, frequency : Occasionally finds it hard to stick to  , 1  , 0.003
# Value, N observations, frequency : Maintaining a healthy diet during barbecues  , 1  , 0.003
# Value, N observations, frequency : Anxiety around 'clean eating'  , 1  , 0.003
# Value, N observations, frequency : Balancing with kidney health  , 1  , 0.003
# Value, N observations, frequency : Reducing caffeine intake  , 1  , 0.003
# Value, N observations, frequency : Managing weight due to metabolic disorder  , 1  , 0.003
# ...
# Value, N observations, frequency : ["Walking","Running","Pilates","Yoga","Swimming"]  , 1  , 0.003
# Value, N observations, frequency : nan  , 0  , 0.0
# Value, N observations, frequency : ["Swimming","Running","Walking","Yoga","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Yoga","Swimming","Walking","Dancing","Cycling"]  , 4  , 0.013
# Value, N observations, frequency : ["Walking","Running","Swimming","Cycling","Dancing"]  , 1  , 0.003
# Value, N observations, frequency : ["Yoga","Swimming","Walking","Dancing (hip-hop)","Cycling"]  , 2  , 0.007
# Value, N observations, frequency : ["Running","Swimming","Walking","Cycling","Yoga"]  , 3  , 0.01
# Value, N observations, frequency : ["Running","Walking","Swimming","Weightlifting","Yoga"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Swimming","Yoga","Running","Pilates"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Running","Yoga","Swimming","Cycling"]  , 3  , 0.01
# Value, N observations, frequency : ["Yoga","Swimming","Running","Walking","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Aerobics","Yoga","Swimming","Running","Walking"]  , 1  , 0.003
# Value, N observations, frequency : ["Yoga","Walking","Dancing","Cycling","Swimming"]  , 1  , 0.003
# Value, N observations, frequency : ["Yoga","Swimming","Running","Walking","Dancing"]  , 5  , 0.017
# Value, N observations, frequency : ["Running","Walking","Swimming","Cycling","Dancing"]  , 6  , 0.02
# Value, N observations, frequency : ["Running","Swimming","Walking","Cycling"]  , 2  , 0.007
# Value, N observations, frequency : ["Running","Walking","Swimming","Yoga","Dancing"]  , 2  , 0.007
# Value, N observations, frequency : ["Running (marathons, sprints, trail running)","Walking","Swimming","Cycling","Weightlifting"]  , 1  , 0.003
# Value, N observations, frequency : ["Pilates","Yoga","Running","Walking","Dancing"]  , 1  , 0.003
# Value, N observations, frequency : ["Yoga","Pilates","Walking","Running (marathons, sprints, trail running)","Swimming"]  , 1  , 0.003
# Value, N observations, frequency : ["Yoga","Swimming","Walking","Running","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Running","Yoga","Swimming","Dancing"]  , 7  , 0.023
# Value, N observations, frequency : ["Running (marathons, sprints, trail running)","Walking","Yoga","Swimming","Dancing (ballet, hip-hop, jazz, ballroom)"]  , 2  , 0.007
# Value, N observations, frequency : ["Yoga","Swimming","Walking","Dancing","Tai Chi"]  , 1  , 0.003
# Value, N observations, frequency : ["Running","Walking","Swimming","Cycling","Yoga"]  , 5  , 0.017
# Value, N observations, frequency : ["Yoga","Walking","Dancing","Swimming","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Yoga","Swimming","Dancing (hip-hop)","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Running","Swimming","Yoga","Weightlifting"]  , 2  , 0.007
# Value, N observations, frequency : ["Swimming","Walking","Dancing (hip-hop)","Cycling","Yoga"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Swimming","Yoga","Dancing","Cycling"]  , 2  , 0.007
# Value, N observations, frequency : ["Running","Walking","Swimming","Weightlifting","Cycling"]  , 4  , 0.013
# Value, N observations, frequency : ["Walking","Running (sprints)","Swimming","Cycling","Weightlifting"]  , 1  , 0.003
# Value, N observations, frequency : ["Running","Walking","Swimming","Cycling","Weightlifting"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Dancing","Swimming","Yoga","Cycling"]  , 2  , 0.007
# Value, N observations, frequency : ["Aerobics","Walking","Running","Swimming","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Running","Walking","Yoga","Swimming"]  , 2  , 0.007
# Value, N observations, frequency : ["Walking","Swimming","Running","Yoga","Cycling"]  , 5  , 0.017
# Value, N observations, frequency : ["Walking","Yoga","Swimming","Running (sprints)","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Running","Swimming","Weightlifting","Dancing"]  , 1  , 0.003
# Value, N observations, frequency : ["Running","Walking","Cycling","Swimming","Yoga"]  , 1  , 0.003
# Value, N observations, frequency : ["Running","Yoga","Swimming","Walking","Dancing"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Yoga","Running","Swimming","Dancing"]  , 2  , 0.007
# Value, N observations, frequency : ["Walking","Yoga","Running","Swimming","Cycling"]  , 3  , 0.01
# Value, N observations, frequency : ["Yoga","Running","Walking","Dancing","Cycling"]  , 2  , 0.007
# Value, N observations, frequency : ["Walking","Swimming","Running","Yoga","Dancing"]  , 3  , 0.01
# Value, N observations, frequency : ["Walking","Yoga","Swimming","Running (sprints)"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Swimming","Running","Cycling","Yoga"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Running","Yoga","Dancing","Swimming"]  , 1  , 0.003
# Value, N observations, frequency : ["Running","Swimming","Walking","Hiking","Dancing"]  , 1  , 0.003
# Value, N observations, frequency : ["Hiking","Yoga","Swimming","Walking","Dancing"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Swimming","Cycling","Yoga","Running"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Swimming","Yoga","Cycling","Dancing"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Dancing (hip-hop)","Running (marathons, sprints, trail running)","Yoga","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Yoga","Running","Swimming","Walking","Dancing"]  , 1  , 0.003
# Value, N observations, frequency : ["Running","Walking","Dancing","Swimming","Yoga"]  , 2  , 0.007
# Value, N observations, frequency : ["Walking","Yoga","Swimming","Cycling","Dancing"]  , 2  , 0.007
# Value, N observations, frequency : ["Running","Walking","Dancing","Yoga","Swimming"]  , 1  , 0.003
# Value, N observations, frequency : ["Running","Swimming","Walking","Yoga","Dancing"]  , 3  , 0.01
# Value, N observations, frequency : ["Yoga","Walking","Swimming","Dancing","Tai Chi"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Running","Swimming","Hiking","Yoga"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Swimming","Running","Cycling","Hiking"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Running","Swimming","Yoga","Dancing"]  , 4  , 0.013
# Value, N observations, frequency : ["Yoga","Running","Walking","Swimming","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Running","Swimming","Walking","Dancing","Tai Chi"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Running","Swimming","Dancing","Yoga"]  , 2  , 0.007
# Value, N observations, frequency : ["Walking","Swimming","Yoga","Pilates","Dancing (ballet, hip-hop, jazz, ballroom)"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Swimming","Running","Yoga","Hiking"]  , 2  , 0.007
# Value, N observations, frequency : ["Running","Swimming","Walking","Hiking","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Swimming","Running","Dancing","Pilates"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Swimming","Running (marathons, sprints, trail running)","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Running","Swimming","Walking","Cycling","Weightlifting"]  , 2  , 0.007
# Value, N observations, frequency : ["Running","Swimming","Yoga","Walking","Dancing"]  , 2  , 0.007
# Value, N observations, frequency : ["Aerobics","Yoga","Running","Walking","Dancing"]  , 1  , 0.003
# Value, N observations, frequency : ["Running (marathons, sprints, trail running)","Walking","Swimming","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Running","Swimming","Walking","Dancing","Cycling"]  , 7  , 0.023
# Value, N observations, frequency : ["Running","Walking","Swimming","Yoga","Cycling"]  , 6  , 0.02
# Value, N observations, frequency : ["Running","Swimming","Walking","Weightlifting","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Swimming","Running","Yoga","Weightlifting"]  , 2  , 0.007
# Value, N observations, frequency : [{"activities":"Walking"},{"activities":"Running"},{"activities":"Swimming"},{"activities":"Cycling"},{"activities":"Weightlifting"}]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Yoga","Swimming"]  , 3  , 0.01
# Value, N observations, frequency : ["Walking","Swimming","Yoga","Running","Cycling"]  , 2  , 0.007
# Value, N observations, frequency : ["Running (sprints)","Walking","Swimming","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : [{"activities":"Walking"},{"activities":"Cycling"},{"activities":"Hiking"},{"activities":"Swimming"},{"activities":"Yoga"}]  , 1  , 0.003
# Value, N observations, frequency : ["Running","Walking","Swimming","Yoga","Hiking"]  , 1  , 0.003
# Value, N observations, frequency : [{"activities":"Walking"},{"activities":"Yoga"},{"activities":"Swimming"},{"activities":"Running"},{"activities":"Dancing"}]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Running (marathons, sprints, trail running)","Swimming","Cycling","Yoga"]  , 1  , 0.003
# Value, N observations, frequency : ["Aerobics","Yoga","Walking","Swimming","Dancing"]  , 2  , 0.007
# Value, N observations, frequency : ["Swimming","Running","Cycling","Walking","Yoga"]  , 1  , 0.003
# Value, N observations, frequency : ["Swimming","Running","Walking","Dancing","Yoga"]  , 4  , 0.013
# Value, N observations, frequency : ["Walking","Swimming","Running","Cycling","Dancing"]  , 1  , 0.003
# Value, N observations, frequency : ["Yoga","Running","Walking","Swimming"]  , 1  , 0.003
# Value, N observations, frequency : ["Aerobics","Yoga","Running (marathons, sprints, trail running)","Walking","Dancing (ballet, hip-hop, jazz, ballroom)"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Swimming","Dancing","Cycling","Yoga"]  , 2  , 0.007
# Value, N observations, frequency : ["Running","Yoga","Swimming","Walking","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Yoga","Dancing","Walking","Swimming","Running"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Hiking"]  , 1  , 0.003
# Value, N observations, frequency : ["Yoga","Running","Walking"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Yoga","Swimming","Tai Chi","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Swimming","Yoga","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Running","Swimming","Walking","Yoga","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Running (marathons, sprints, trail running)","Walking","Dancing (ballet, hip-hop, jazz, ballroom)","Yoga","Swimming"]  , 2  , 0.007
# Value, N observations, frequency : ["Walking","Yoga","Swimming","Dancing","Tai Chi"]  , 1  , 0.003
# Value, N observations, frequency : ["Yoga","Walking","Swimming","Dancing (hip-hop)","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Yoga","Running","Cycling","Swimming"]  , 1  , 0.003
# Value, N observations, frequency : [{"activities":"Running"},{"activities":"Swimming"},{"activities":"Walking"},{"activities":"Cycling"},{"activities":"Yoga"}]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Running","Yoga","Weightlifting","Swimming"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Yoga","Swimming","Cycling"]  , 2  , 0.007
# Value, N observations, frequency : ["Walking","Running","Yoga","Swimming","Hiking"]  , 1  , 0.003
# Value, N observations, frequency : [{"activities":"Running"},{"activities":"Walking"},{"activities":"Swimming"},{"activities":"Cycling"},{"activities":"Yoga"}]  , 1  , 0.003
# Value, N observations, frequency : ["Running","Walking","Yoga","Dancing","Swimming"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Dancing","Yoga","Swimming","Cycling"]  , 2  , 0.007
# Value, N observations, frequency : ["Running","Swimming","Walking","Cycling","Dancing"]  , 1  , 0.003
# Value, N observations, frequency : ["Running (marathons, sprints, trail running)","Walking","Swimming","Dancing (ballet, hip-hop, jazz, ballroom)","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Yoga","Swimming","Strength Training","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Swimming","Running","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Swimming","Walking","Running","Yoga","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Running","Walking","Cycling","Swimming","Weightlifting"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Yoga","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Dancing","Swimming","Cycling","Yoga"]  , 1  , 0.003
# Value, N observations, frequency : ["Running","Walking","Swimming","Yoga","Weightlifting"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Hiking","Swimming","Yoga","Running (marathons, sprints, trail running)"]  , 1  , 0.003
# Value, N observations, frequency : ["Running (marathons, sprints, trail running)","Walking","Swimming","Dancing (ballet, hip-hop, jazz, ballroom)","Weightlifting"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Swimming","Running","Dancing","Cycling"]  , 1  , 0.003
# Value, N observations, frequency : ["Walking","Yoga","Swimming","Running","Weightlifting"]  , 1  , 0.003
# No. of NANs  3
#
#  alcohol_consumption :
# Value, N observations, frequency : Low  , 265  , 0.883
# Value, N observations, frequency : Moderate  , 34  , 0.113
# Value, N observations, frequency : nan  , 0  , 0.0
# No. of NANs  1
#
#  stress_level :
# Value, N observations, frequency : Moderate  , 161  , 0.537
# Value, N observations, frequency : Low  , 138  , 0.46
# Value, N observations, frequency : nan  , 0  , 0.0
# No. of NANs  1
#
#  screen_time_per_day :
# Value, N observations, frequency : 4.0  , 73  , 0.243
# Value, N observations, frequency : 3.0  , 156  , 0.52
# Value, N observations, frequency : 2.0  , 70  , 0.233
# Value, N observations, frequency : nan  , 0  , 0.0
# No. of NANs  1
#
#  physical_activity :
# Value, N observations, frequency : Moderate  , 288  , 0.96
# Value, N observations, frequency : High  , 10  , 0.033
# Value, N observations, frequency : Low  , 1  , 0.003
# Value, N observations, frequency : nan  , 0  , 0.0
# No. of NANs  1
#
#  smoking_status :
# Value, N observations, frequency : False  , 297  , 0.99
# Value, N observations, frequency : True  , 2  , 0.007
# Value, N observations, frequency : nan  , 0  , 0.0
# No. of NANs  1
#
#  drug_usage :
# Value, N observations, frequency : False  , 298  , 0.993
# Value, N observations, frequency : nan  , 0  , 0.0
# No. of NANs  2
#
#  average_sleep_duration_hours :
# Value, N observations, frequency : nan  , 0  , 0.0
# Value, N observations, frequency : 7.3  , 21  , 0.07
# Value, N observations, frequency : 7.0  , 20  , 0.067
# Value, N observations, frequency : 8.0  , 23  , 0.077
# Value, N observations, frequency : 7.4  , 17  , 0.057
# Value, N observations, frequency : 7.2  , 23  , 0.077
# Value, N observations, frequency : 7.6  , 15  , 0.05
# Value, N observations, frequency : 8.1  , 15  , 0.05
# Value, N observations, frequency : 7.8  , 19  , 0.063
# Value, N observations, frequency : 7.1  , 16  , 0.053
# Value, N observations, frequency : 7.5  , 7  , 0.023
# Value, N observations, frequency : 7.9  , 12  , 0.04
# Value, N observations, frequency : 7.7  , 21  , 0.07
# Value, N observations, frequency : 6.9  , 4  , 0.013
# Value, N observations, frequency : 8.2  , 2  , 0.007
# No. of NANs  85
#
#  average_blood_pressure :
# Value, N observations, frequency : nan  , 0  , 0.0
# Value, N observations, frequency : 120/80  , 229  , 0.763
# Value, N observations, frequency : 120/80 mmHg  , 2  , 0.007
# Value, N observations, frequency : 130/85  , 5  , 0.017
# Value, N observations, frequency : 130/80  , 7  , 0.023
# No. of NANs  57
#
#  health_related_activities :
# Value, N observations, frequency : nan  , 0  , 0.0
# Value, N observations, frequency : ["Walking","Running (sprints)","Yoga","Cycling","Dancing (hip-hop)"]  , 1  , 0.003
# No. of NANs  299

# %%
# Going through the above, we can see that the following features are not useful for clustering/classification,
# simply because they have too many missing values. 
cols_to_drop.extend(['average_sleep_duration', 'systolic', 'diastolic', 'health_related_activities'])

# Similarly, since current_country_of_residence is the same for all patients, it is not useful for clustering/classification
cols_to_drop.append('current_country_of_residence')

# Since all non-nan values for drug_usage are False, it is not useful for clustering/classification
cols_to_drop.append('drug_usage')

# Since ethnicity and country_of_birth are almost equivalent, we can drop one of them
# Finally, since state_code and country_code contain the same information, we can drop one of them
cols_to_drop.append('ethnicity')
cols_to_drop.append('state_code')

# Drop the columns we don't need
df.drop(cols_to_drop, axis=1, inplace=True)

# %% [markdown]
# Step 2: Convert features with potential to be numeric to numeric features. In our case, this amounts to transforming the average_blood_pressure feature

# %%
# Let's look at the average_blood_presure feature
unique = df['average_blood_pressure'].unique();
# calculate frequency of each value
for val in unique:
    if val not in ['nan']:
        N = len(df[df['average_blood_pressure'] == val])
        print("Value, N observations, frequency :", val," ,", N, " ,", np.round(N/Nrows,3))

print("No. of NANs ", len(df[df['average_blood_pressure'].isna()]))
# Out:
# Value, N observations, frequency : nan  , 0  , 0.0
# Value, N observations, frequency : 120/80  , 229  , 0.763
# Value, N observations, frequency : 120/80 mmHg  , 2  , 0.007
# Value, N observations, frequency : 130/85  , 5  , 0.017
# Value, N observations, frequency : 130/80  , 7  , 0.023
# No. of NANs  57

# %%
# To convert this feature into a numerical one (well, two), we will split it into two features: systolic and diastolic

# Get rid of the unit
df['average_blood_pressure'] = df['average_blood_pressure'].str.replace(' mmHg', '')

# Split the feature into two
df[['systolic','diastolic']] = df['average_blood_pressure'].str.split('/',expand=True)

# Convert the two new features to numeric
df['systolic'] = pd.to_numeric(df['systolic'])
df['diastolic'] = pd.to_numeric(df['diastolic'])

# Drop the now redundant average_blood_pressure feature
df.drop('average_blood_pressure', axis=1, inplace=True)

# %%
# Get rid of units and convert to numeric for the remaining relevant features

# remove ' cm' suffix, then convert to float
df['height'] = df['height'].str.replace(' cm', '')
df['height'] = df['height'].astype(float)

# Remove ' kg' suffix from 'weight' and convert to float
df['weight'] = df['weight'].str.replace(' kg', '')
df['weight'] = df['weight'].astype(float)

# %% [markdown]
# Step 3: Fill out (=impute) missing numeric values

# %%
# Let's look at the number of Nans for each numeric column
num_cols = df.select_dtypes(include=['float64', 'int64']).columns

Nrows = df.shape[0]
# Go through each column except for the ones we want to drop
for col in num_cols:
    # get unique values in column
    unique = df[col].unique();
    print(col,":")
    print("No. of NANs ", len(df[df[col].isna()]))
# Out:
# age :
# No. of NANs  0
# weight :
# No. of NANs  1
# height :
# No. of NANs  1
# bmi :
# No. of NANs  1
# average_daily_step_count :
# No. of NANs  0
# resting_heart_rate :
# No. of NANs  0
# heart_rate_variability :
# No. of NANs  0
# average_blood_glucose :
# No. of NANs  0
# average_fasting_glucose :
# No. of NANs  1
# number_of_children :
# No. of NANs  88
# screen_time_per_day :
# No. of NANs  1
# average_sleep_duration_hours :
# No. of NANs  85
# systolic :
# No. of NANs  57
# diastolic :
# No. of NANs  57

# %%
# We see that some features have as much as 88 (= 30 %) missing values, which is much more than we would like. One could certainly
# argue that these features should be dropped. We choose to keep them in the following, however.

# Too impute missing values, we introduce the following functions

# This imputer only simply replace the missing values with mean, median or most frequent value of that feature
simple_imputer = SimpleImputer(missing_values=np.nan, strategy='mean') 

# This imputer considers all numeric features and assigns to each missing value the feature mean of the n nearest neighbors
knn_imputer = KNNImputer(missing_values = np.nan, n_neighbors = 5)

# We will use the knn imputer, since it considers all numeric features to find the most similar neighbors:
df.loc[:, num_cols] = knn_imputer.fit_transform(df.loc[:, num_cols] )

# Finally, since non-integer number of childrens are not very meaningful, we'll round the estimated no of children
df['number_of_children'] = df['number_of_children'].round(decimals = 0)

# %% [markdown]
# Step 4: Convert categorical features to numeric ones
# * Convert features with two values to boolean features
# * Label encode features with order
# * (Cleverly) group and one hot encode features without order

# %%
# Convert features with two values to boolean

bool_cols = ['gender', 'stress_level', 'physical_activity', 'alcohol_consumption']

alcohol_consumption_order = {'Low': 0, 'Moderate': 1}
df['alcohol_consumption'] = df['alcohol_consumption'].map(alcohol_consumption_order)

gender_order = {'Male': 0, 'Female': 1}
df['gender'] = df['gender'].map(gender_order)

# Group low and moderate together since only 1 person reported low stress
stress_level_order = {'Low': 0, 'Moderate': 0, 'High': 1}
df['stress_level'] = df['stress_level'].map(stress_level_order)

physical_activity_order = {'Low': 0, 'Moderate': 1}
df['physical_activity'] = df['physical_activity'].map(physical_activity_order)

# %% [markdown]
# #### Ranking ordered features (ordinal features) using label encoding:
#
# Since one-hot encoding can increase the no. of features dramatically,
# we will use label encoding for ordinal features. Sometimes, the order is
# very clear (e.g. low, mid, high, very high), and sometimes we have to be
# a bit creative.
#
# For example, we could rank country_of_birth by GDP per capita, and we could
# rank state_name by average BMI. We could also rank housing by the average
# size of each housing type, and tenure from renting to owning to owning without mortgage.
#
# In the following, we'll convert the activity and state_name features by finding a metric for the order and then using label encoding. We'll start by reformatting the activities feature to make them easier to work with, after which we'll transform category to a numerical one.

# %%
## Reformatting the activity feature ##

unique_list = []
# List of extra stuff we want to drop
discard_list = ['"activities":', ' (sprints)', '(jazz)', '(hip-hop)', \
                '(marathons, sprints, trail running)', '(ballet, hip-hop, jazz, ballroom)']

# Go through each row in the activities column
for i, x in enumerate(df.loc[:,'activities']):
    x_cleaned = []
    # Avoid nans
    if type(x) is float:
        continue
    # Remove the extra stuff
    for el in discard_list:
        x = x.replace(el,'')
    # Split the string into a list of activities
    for el in list(x.split(',')):
        # Remove extra characters
        el = el.strip("['").strip("']").strip('{"').strip('}').strip('"').strip()
        # Add to activity to list of activities
        x_cleaned.append(el)
        # Add to list of unique activities if not already there
        if el not in unique_list:
            unique_list.append(el)

    # Replace the original string with the cleaned list
    df.loc[i,'activities'] = str(x_cleaned)


# Let's take a look at some of the reformatted rows
print(df.loc[:5,'activities'])

print("\nUnique activities: ", unique_list)
# Out:
# 0    ['Running', 'Walking', 'Yoga', 'Swimming', 'Da...
# 1    ['Walking', 'Swimming', 'Running', 'Yoga', 'Da...
# 2    ['Running', 'Walking', 'Swimming', 'Dancing', ...
# 3    ['Walking', 'Yoga', 'Swimming', 'Dancing', 'Cy...
# 4    ['Running', 'Walking', 'Yoga', 'Swimming', 'Da...
# 5                   ['Running', 'Walking', 'Swimming']
# Name: activities, dtype: object
#
# Unique activities:  ['Running', 'Walking', 'Yoga', 'Swimming', 'Dancing', 'Cycling', 'Weightlifting', 'Hiking', 'Pilates', 'Tai Chi', 'Aerobics', 'Strength Training']

# %% [markdown]
# The goal is to translate the activities into a measure of peoples physical fitness/health.
# We will very naively assume that the number of listed activites correspond to the physical activity level
# of each patient.
# There are many other ways of transforming these categories. One could e.g. map each activity to the average calorie burning rate and then add the burning rates for each row. Feel free to play around and try different things!

# %%
## Map each activity list to the number of activities on that list
for i, x in enumerate(df.loc[:,'activities']):
    if type(x) is not float:
        df.loc[i,'activities'] = len(list(x.split(',')))

# %% [markdown]
# As another example, let's introduce order into the state name feature and then use label encoding. In particular, let's map the state_names, which are not necessarily very informative as is, onto the obesity prevalences (% of obese people) of the corresponding states

# %%
# As an example, let us map the state_name feauture onto the prevalence of obsese people (BMI > 30) in the given stats
# The obesity prevalence data is from 2021 and can be found and downloaded on
#  https://www.cdc.gov/obesity/data/prevalence-maps.html

obesity_df = pd.read_csv('data/Obesity-prevalence-by-state-2021.csv')
obesity_order = {}

# Make obesity order dictionary
for row in range(len(obesity_df)):
    try:
        obesity_order.update({f'{obesity_df.loc[row,"State"]}': float(obesity_df.loc[row,'Prevalence'])})
    except:
        pass

del_list = []
for key in obesity_order.keys():
    if key not in df['state_name'].unique():
        del_list.append(key)
   
for key in del_list:
    del obesity_order[key]

df['state_name'] = df['state_name'].map(obesity_order)

# %% [markdown]
# In the following, we'll show two examples of how to group and transform features using one-hot (or dummy) encoding. One-hot encoding has the advantage
# that is does not introduce any order between features like label encoding does, but the drawback that K different categories of a feature will be transformed into K or K-1 new features, and so the total number of features can become very large, which can hurt performance. For this reasons, if a feature has many categories, these categories are often grouped in straightforward (simply group rare categories) or clever (use domain knowledge to make groups).

# %%
## Group the observations of the mother feature

# Print out each category and its frequency 
for col in ['mother']:
    # get unique values in column
    unique = df[col].unique();
    print("\n", col,":")
    # calculate frequency of each value
    for val in unique:
        if val not in ['nan']:
            N = len(df[df[col] == val])
            print("Value, N observations, frequency :", val," ,", N, " ,", np.round(N/Nrows,3))

    print("No. of NANs ", len(df[df[col].isna()]))

# Group different spellings
mother_map = {'Type 2 Diabetes': 'Type 2 diabetes', }
df['mother'].replace({'Type 2 Diabetes': 'Type 2 diabetes'}, inplace=True)

# Group all values except for 'Type 2 diabetes' and 'Hypertension' into 'No known health issues'
mask = (df['mother'] == 'Type 2 diabetes') | ( df['mother'] == 'Hypertension')
df.loc[~mask, 'mother'] = 'No known health issues'

print("\nvalues of mother after grouping: ", df['mother'].unique())
# Out:
#  mother :
# Value, N observations, frequency : Hypertension  , 7  , 0.023
# Value, N observations, frequency : No known health issues  , 90  , 0.3
# Value, N observations, frequency : No known medical conditions  , 170  , 0.567
# Value, N observations, frequency : No history of diabetes  , 6  , 0.02
# Value, N observations, frequency : No known health conditions  , 2  , 0.007
# Value, N observations, frequency : Type 2 diabetes  , 13  , 0.043
# Value, N observations, frequency : No significant medical history  , 1  , 0.003
# Value, N observations, frequency : No history of hypertension  , 2  , 0.007
# Value, N observations, frequency : No history of heart disease  , 1  , 0.003
# Value, N observations, frequency : Type 2 Diabetes  , 3  , 0.01
# Value, N observations, frequency : No history of CVD  , 3  , 0.01
# Value, N observations, frequency : No history of heart disease or diabetes  , 1  , 0.003
# Value, N observations, frequency : No history of cardiovascular diseases  , 1  , 0.003
# No. of NANs  0
#
# values of mother after grouping:  ['Hypertension' 'No known health issues' 'Type 2 diabetes']

# %%
## Group similar (and also rare) categories of the diet_type features

# Go through each column except for the ones we want to drop
for col in ['diet_type']:
    # get unique values in column
    unique = df[col].unique();
    print("\n", col,":")
    # calculate frequency of each value
    for val in unique:
        if val not in ['nan']:
            N = len(df[df[col] == val])
            print("Value, N observations, frequency :", val," ,", N, " ,", np.round(N/Nrows,3))

    print("No. of NANs ", len(df[df[col].isna()]))

# Group different spellings
df['diet_type'].replace({'Balanced Diet': 'Balanced'}, inplace=True)

# Group plant based diets together
df['diet_type'].replace({'Vegan': 'Plant-based', 'Vegetarian': 'Plant-based'}, inplace=True)

# Group the remaining values into 'Other'
mask = (df['diet_type'] == 'Balanced') | ( df['diet_type'] == 'Plant-based') | ( df['diet_type'] == 'Mediterranean') | ( df['diet_type'] == 'Low-carb')
df.loc[~mask, 'diet_type'] = 'Other'

print("\nvalues of diet_type after grouping: ", df['diet_type'].unique())
# Out:
#  diet_type :
# Value, N observations, frequency : Mediterranean  , 47  , 0.157
# Value, N observations, frequency : Balanced  , 177  , 0.59
# Value, N observations, frequency : Gluten-free  , 15  , 0.05
# Value, N observations, frequency : Keto  , 1  , 0.003
# Value, N observations, frequency : Diabetic-friendly  , 6  , 0.02
# Value, N observations, frequency : Omnivore  , 7  , 0.023
# Value, N observations, frequency : Low-carb  , 8  , 0.027
# Value, N observations, frequency : Low FODMAP  , 1  , 0.003
# Value, N observations, frequency : Crohn's disease-friendly diet  , 1  , 0.003
# Value, N observations, frequency : Low Protein  , 1  , 0.003
# Value, N observations, frequency : Vegetarian  , 11  , 0.037
# Value, N observations, frequency : Low-FODMAP  , 2  , 0.007
# Value, N observations, frequency : Anti-inflammatory diet  , 1  , 0.003
# Value, N observations, frequency : Gestational  , 1  , 0.003
# Value, N observations, frequency : Plant-based  , 2  , 0.007
# Value, N observations, frequency : Salt-restricted  , 1  , 0.003
# Value, N observations, frequency : Vegan  , 2  , 0.007
# Value, N observations, frequency : Low Glycemic Index  , 2  , 0.007
# Value, N observations, frequency : Intermittent Fasting  , 2  , 0.007
# Value, N observations, frequency : Multiple Sclerosis Diet  , 1  , 0.003
# Value, N observations, frequency : Ayurvedic  , 1  , 0.003
# Value, N observations, frequency : Anti-Inflammatory Diet  , 1  , 0.003
# Value, N observations, frequency : High Protein  , 1  , 0.003
# Value, N observations, frequency : Halal  , 3  , 0.01
# Value, N observations, frequency : Low-sodium  , 1  , 0.003
# Value, N observations, frequency : Balanced Diet  , 2  , 0.007
# Value, N observations, frequency : Anti-inflammatory  , 2  , 0.007
# No. of NANs  0
#
# values of diet_type after grouping:  ['Mediterranean' 'Balanced' 'Other' 'Low-carb' 'Plant-based']

# %%
## We need this function to do one-hot (or dummy) encoding
def do_dummy_encoding(dataframe, target_columns, prefix_list, drop_first = False):
    """
    For each cateogrical column with categories (l1,...,ln), this function transform the category into n ( if drop_first = False)
    or n-1 columns, where [0,0,...,0] represents l1,
    [1,0,...,0] rep. l2, [0,1,0,...,0] rep l3 etc
    """
    data = dataframe.copy()
    # Build dummy index dataframe
    dummy_columns = pd.get_dummies(data[target_columns], prefix = prefix_list, drop_first=drop_first)

    ## Append new columns to dataframe
    data = pd.concat([data, dummy_columns], axis = 1)

    ## Drop original columns
    data.drop(columns = target_columns, inplace=True)
    return data

# %% [markdown]
# Having grouped the categories of mother and diet_type into fewer categories, let us transform the features using one hot encoding

# %%
onehot_cols = ['mother', 'diet_type']

for i, col in enumerate(onehot_cols):
    # Use onehot_cols[i] as prefix for the new columns
    # If drop_first = False, the first category will be included in the new columns
    # If drop_first = True, the first category will be dropped, meaning that
    #  if all new columns are 0, the category is the first one. This is the most
    #  efficient way of doing it, but it has the price that we have to remember that
    # the first category is represented like this
    df = do_dummy_encoding(df, col, onehot_cols[i], drop_first = False)

# Let's take a look at the new columns
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   gender                         300 non-null    int64
#  1   age                            300 non-null    int64
#  2   country_of_birth               300 non-null    object
#  3   weight                         300 non-null    float64
#  4   height                         300 non-null    float64
#  5   bmi                            300 non-null    float64
#  6   average_daily_step_count       300 non-null    int64
#  7   resting_heart_rate             300 non-null    int64
#  8   heart_rate_variability         300 non-null    float64
#  9   average_blood_glucose          300 non-null    float64
#  10  average_fasting_glucose        300 non-null    float64
#  11  specific_preferences           292 non-null    object
#  12  challenges                     275 non-null    object
#  13  father                         300 non-null    object
#  14  current_city_of_residence      300 non-null    object
#  15  state_name                     270 non-null    float64
#  16  housing_type                   300 non-null    object
#  17  housing_tenure                 300 non-null    object
#  18  marital_status                 300 non-null    object
#  19  has_children                   300 non-null    bool
#  20  number_of_children             300 non-null    float64
#  21  living_alone                   300 non-null    bool
#  22  sexual_orientation             300 non-null    object
#  23  activities                     297 non-null    object
#  24  alcohol_consumption            299 non-null    float64
#  25  stress_level                   299 non-null    float64
#  26  screen_time_per_day            300 non-null    float64
#  27  physical_activity              289 non-null    float64
#  28  smoking_status                 299 non-null    object
#  29  average_sleep_duration_hours   300 non-null    float64
#  30  systolic                       300 non-null    float64
#  31  diastolic                      300 non-null    float64
#  32  mother_Hypertension            300 non-null    bool
#  33  mother_No known health issues  300 non-null    bool
#  34  mother_Type 2 diabetes         300 non-null    bool
#  35  diet_type_Balanced             300 non-null    bool
#  36  diet_type_Low-carb             300 non-null    bool
#  37  diet_type_Mediterranean        300 non-null    bool
#  38  diet_type_Other                300 non-null    bool
#  39  diet_type_Plant-based          300 non-null    bool
# dtypes: bool(10), float64(15), int64(4), object(11)
# memory usage: 73.4+ KB
# None

# %% [markdown]
# In the following, we simply encode the remaining categorical features to numerical ones by label encoding.
# This naive approach introduces false order between different categories and is not in general the right approach
# when no inherent order is present between categories.
#
# #### **You are expected to encode the remaining categorical features in the best way, e.g. using the methods illustrated above.**
#
# **NB:** Make sure you remove a feature from the list below once you have found another way to encode it!

# %%
# Use LabelEncoder to convert the remaining columns to numerical values
labels = ['country_of_birth', 'current_city_of_residence', 'housing_type', 'housing_tenure', 'marital_status', 'sexual_orientation',
              'father', 'specific_preferences', 'challenges', 'activities']
labelencoder = LabelEncoder()
for label in labels:
    df[label] = labelencoder.fit_transform(df[label])

# %%
# Having converted all features to numerical values, we can now imputate the remaining NaNs

# This imputer considers all numeric features and assigns to each missing value the feature mean of the n nearest neighbors
knn_imputer = KNNImputer(missing_values = np.nan, n_neighbors = 5)

# We will use the knn imputer, since it considers all numeric features to find the most similar neighbors:
df.loc[:] = knn_imputer.fit_transform(df.loc[:] )

# Finally, since non-integer number of childrens are not very meaningful, we'll round the estimated no of children
#df['number_of_children'] = df['number_of_children'].round(decimals = 0)

# %% [markdown]
# #### At this point, the data cleaning is completed, and we can proceed by scaling the features and potentially applying PCA analysis to reduce the total number of features.

# %% [markdown]
# ### Excercises:
# - There are some indications that the BMI feature contains errors. Use the height and weight features to calculate the BMI of all patients and replace the potentially wrong BMI values your results
# - Can you fig. out what the nan values in number_of_children should be (before we impute them), given that you also have access to the has_children feature? Once you do, change the nan values before imputation.
# - Just like we mapped the state_name feature onto obesity prevalences, map the country_of_origin to a metric you think might be useful for predicting type 2 diabetes.
# - Inspired by how we grouped the mother and diet_type features, group the father feature, and then move it from the label_encoding list to the one-hot encoding list
#  and speficic_preferances features
# - (**To be done on your own time**) Go through the remaining features 'country_of_birth', 'current_city_of_residence', 'housing_type', 'housing_tenure', 'marital_status', 'sexual_orientation',
#                'specific_preferences', 'challenges', 'activities', and figure out the best way to encode them
